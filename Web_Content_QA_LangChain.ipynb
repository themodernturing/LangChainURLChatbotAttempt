# %% [markdown]
# <a href="https://colab.research.google.com/github/themodernturing/LangChainURLChatbotAttempt/blob/main/Web_Content_QA_LangChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install -U langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.10.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting langchain<0.4.0,>=0.3.0 (from langchain-community)
#   Downloading langchain-0.3.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4.0,>=0.3.0 (from langchain-community)
#   Downloading langchain_core-0.3.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting langsmith<0.2.0,>=0.1.112 (from langchain-community)
#   Downloading langsmith-0.1.122-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain-community)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain<0.4.0,>=0.3.0->langchain-community)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.0->langchain-community) (2.9.1)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.0->langchain-community)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.0->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.0->langchain-community) (4.12.2)
# Collecting httpx<1,>=0.23.0 (from langsmith<0.2.0,>=0.1.112->langchain-community)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.112->langchain-community)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 904.6 kB/s eta 0:00:00
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (3.7.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain-community)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.0->langchain-community) (2.23.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-community) (1.2.2)
# Downloading langchain_community-0.3.0-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 15.1 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain-0.3.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.8 MB/s eta 0:00:00
# Downloading langchain_core-0.3.1-py3-none-any.whl (405 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.1/405.1 kB 7.0 MB/s eta 0:00:00
# Downloading langsmith-0.1.122-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.0/290.0 kB 8.3 MB/s eta 0:00:00
# Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.5 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.9 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.3 MB/s eta 0:00:00
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 7.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: tenacity, python-dotenv, orjson, mypy-extensions, marshmallow, jsonpointer, h11, typing-inspect, jsonpatch, httpcore, pydantic-settings, httpx, dataclasses-json, langsmith, langchain-core, langchain-text-splitters, langchain, langchain-community
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# Successfully installed dataclasses-json-0.6.7 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.0 langchain-community-0.3.0 langchain-core-0.3.1 langchain-text-splitters-0.3.0 langsmith-0.1.122 marshmallow-3.22.0 mypy-extensions-1.0.0 orjson-3.10.7 pydantic-settings-2.5.2 python-dotenv-1.0.1 tenacity-8.5.0 typing-inspect-0.9.0

# %%
# !pip install streamlit unstructured requests beautifulsoup4 urllib3 faiss-cpu transformers sentence-transformers langchain accelerate bitsandbytes cohere langchain-cohere
# Out:
# Collecting streamlit
#   Downloading streamlit-1.38.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting unstructured
#   Downloading unstructured-0.15.12-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (2.0.7)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.1.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.34.2)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Collecting cohere
#   Downloading cohere-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-cohere
#   Downloading langchain_cohere-0.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.8.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Collecting watchdog<5,>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.2-py3-none-manylinux2014_x86_64.whl.metadata (38 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.2.0)
# Collecting filetype (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.9.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.9.0)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2024.4.27-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.25.9-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.66.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.9.5)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.4.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.1)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.122)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.1)
# Collecting boto3<2.0.0,>=1.34.0 (from cohere)
#   Downloading boto3-1.35.22-py3-none-any.whl.metadata (6.6 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere)
#   Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.27.2)
# Collecting httpx-sse==0.4.0 (from cohere)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting parameterized<0.10.0,>=0.9.0 (from cohere)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.23.3)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere)
#   Downloading types_requests-2.32.0.20240914-py3-none-any.whl.metadata (1.9 kB)
# Collecting langchain-experimental>=0.3.0 (from langchain-cohere)
#   Downloading langchain_experimental-0.3.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Collecting botocore<1.36.0,>=1.35.22 (from boto3<2.0.0,>=1.34.0->cohere)
#   Downloading botocore-1.35.22-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.34.0->cohere)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2.0.0,>=1.34.0->cohere)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.0->langchain) (1.33)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain-experimental>=0.3.0->langchain-cohere) (0.3.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->unstructured) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (1.4.2)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: cryptography>=3.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (43.0.1)
# Collecting deepdiff>=6.0 (from unstructured-client->unstructured)
#   Downloading deepdiff-8.0.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client->unstructured)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (1.6.0)
# Collecting pypdf>=4.0 (from unstructured-client->unstructured)
#   Downloading pypdf-5.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting requests-toolbelt>=1.0.0 (from unstructured-client->unstructured)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Collecting orderly-set==5.2.2 (from deepdiff>=6.0->unstructured-client->unstructured)
#   Downloading orderly_set-5.2.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental>=0.3.0->langchain-cohere) (2.5.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-experimental>=0.3.0->langchain-cohere) (1.0.1)
# Downloading streamlit-1.38.0-py2.py3-none-any.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 33.7 MB/s eta 0:00:00
# Downloading unstructured-0.15.12-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 35.9 MB/s eta 0:00:00
# Downloading faiss_cpu-1.8.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 39.7 MB/s eta 0:00:00
# Downloading sentence_transformers-3.1.0-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 19.1 MB/s eta 0:00:00
# Downloading bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl (137.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 4.9 MB/s eta 0:00:00
# Downloading cohere-5.9.2-py3-none-any.whl (222 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 kB 11.9 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain_cohere-0.3.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.4 MB/s eta 0:00:00
# Downloading boto3-1.35.22-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 11.1 MB/s eta 0:00:00
# Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 57.1 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.9 MB/s eta 0:00:00
# Downloading langchain_experimental-0.3.0-py3-none-any.whl (206 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.9/206.9 kB 11.3 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 49.9 MB/s eta 0:00:00
# Downloading types_requests-2.32.0.20240914-py3-none-any.whl (15 kB)
# Downloading watchdog-4.0.2-py3-none-manylinux2014_x86_64.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 7.3 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 17.7 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_iso639-2024.4.27-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 19.8 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.1-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 51.6 MB/s eta 0:00:00
# Downloading unstructured_client-0.25.9-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 3.7 MB/s eta 0:00:00
# Downloading botocore-1.35.22-py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 34.3 MB/s eta 0:00:00
# Downloading deepdiff-8.0.1-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 7.7 MB/s eta 0:00:00
# Downloading orderly_set-5.2.2-py3-none-any.whl (11 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.7 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading pypdf-5.0.0-py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 21.5 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.0 MB/s eta 0:00:00
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 7.6 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 7.2 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=0691338f7ab8533c0afa3f5f35728fbca2cb7967a2f901abc53624b285d05e51
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: filetype, watchdog, types-requests, smmap, rapidfuzz, python-magic, python-iso639, pypdf, parameterized, orderly-set, olefile, langdetect, jsonpath-python, jmespath, httpx-sse, fastavro, faiss-cpu, emoji, backoff, requests-toolbelt, python-oxmsg, pydeck, gitdb, deepdiff, botocore, unstructured-client, s3transfer, gitpython, bitsandbytes, unstructured, boto3, streamlit, sentence-transformers, cohere, langchain-experimental, langchain-cohere
# Successfully installed backoff-2.2.1 bitsandbytes-0.43.3 boto3-1.35.22 botocore-1.35.22 cohere-5.9.2 deepdiff-8.0.1 emoji-2.12.1 faiss-cpu-1.8.0.post1 fastavro-1.9.7 filetype-1.2.0 gitdb-4.0.11 gitpython-3.1.43 httpx-sse-0.4.0 jmespath-1.0.1 jsonpath-python-1.0.6 langchain-cohere-0.3.0 langchain-experimental-0.3.0 langdetect-1.0.9 olefile-0.47 orderly-set-5.2.2 parameterized-0.9.0 pydeck-0.9.1 pypdf-5.0.0 python-iso639-2024.4.27 python-magic-0.4.27 python-oxmsg-0.0.1 rapidfuzz-3.9.7 requests-toolbelt-1.0.0 s3transfer-0.10.2 sentence-transformers-3.1.0 smmap-5.0.1 streamlit-1.38.0 types-requests-2.32.0.20240914 unstructured-0.15.12 unstructured-client-0.25.9 watchdog-4.0.2

# %% [markdown]
# # Scraper(Ignore)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import os

# Set to keep track of visited URLs
visited_urls = set()

def get_all_links(url, base_domain):
    try:
        # Make a GET request to fetch the webpage content
        response = requests.get(url)
        response.raise_for_status()  # Ensure the request was successful
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return []

    # Parse the page content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Initialize an empty list to store the links found on this page
    links = []

    # Find all <a> tags with href attributes in the page
    for a_tag in soup.find_all('a', href=True):
        link = a_tag['href']
        # Join the base URL with the href to handle relative URLs
        full_link = urljoin(url, link)

        # Check if the domain of the link matches the base domain
        link_domain = urlparse(full_link).netloc
        if link_domain == base_domain and full_link not in visited_urls:
            links.append(full_link)

    return links

def save_page_content(url, folder_path):
    try:
        # Make a GET request to fetch the webpage content
        response = requests.get(url)
        response.raise_for_status()  # Ensure the request was successful
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return

    # Parse the page content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract the page text
    page_text = soup.get_text(separator=' ', strip=True)

    # Create a file name based on the URL's path
    parsed_url = urlparse(url)
    file_name = parsed_url.path.strip('/').replace('/', '_') or 'home'
    file_path = os.path.join(folder_path, f"{file_name}.txt")

    # Save the text content to a .txt file
    try:
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(page_text)
        print(f"Saved content from {url} to {file_path}")
    except Exception as e:
        print(f"Failed to save content from {url}: {e}")

def crawl_website(url):
    # Parse the base domain from the input URL
    base_domain = urlparse(url).netloc

    # Create a folder with the base domain name to store the content
    folder_path = os.path.join(os.getcwd(), base_domain)
    os.makedirs(folder_path, exist_ok=True)

    # Recursively search and collect links within the same domain
    def recursive_crawl(current_url):
        if current_url in visited_urls:
            return
        visited_urls.add(current_url)

        # Get all internal links from the current page
        links = get_all_links(current_url, base_domain)

        # Save the page content to a .txt file
        save_page_content(current_url, folder_path)

        for link in links:
            if link not in visited_urls:
                recursive_crawl(link)  # Recursively crawl the new link

    # Start crawling from the initial URL
    recursive_crawl(url)

if __name__ == "__main__":
    # Input the URL
    start_url = input("Enter the URL to crawl: ").strip()

    # Start the crawling process
    crawl_website(start_url)

    # Print all the visited links
    print(f"\nCrawling completed. Total links found: {len(visited_urls)}")
    for link in visited_urls:
        print(link)
# https://www.web-scraping.dev/
# Out:
# Enter the URL to crawl: https://www.web-scraping.dev/
# Saved content from https://www.web-scraping.dev/ to /content/www.web-scraping.dev/home.txt
# Saved content from https://www.web-scraping.dev/docs to /content/www.web-scraping.dev/docs.txt
# Saved content from https://www.web-scraping.dev/api/graphql to /content/www.web-scraping.dev/api_graphql.txt
# Saved content from https://www.web-scraping.dev/products to /content/www.web-scraping.dev/products.txt
# Saved content from https://www.web-scraping.dev/reviews to /content/www.web-scraping.dev/reviews.txt
# Saved content from https://www.web-scraping.dev/testimonials to /content/www.web-scraping.dev/testimonials.txt
# Saved content from https://www.web-scraping.dev/login to /content/www.web-scraping.dev/login.txt
# Saved content from https://www.web-scraping.dev/cart to /content/www.web-scraping.dev/cart.txt
# Saved content from https://www.web-scraping.dev/credentials to /content/www.web-scraping.dev/credentials.txt
# Saved content from https://www.web-scraping.dev/credentials?persist to /content/www.web-scraping.dev/credentials.txt
# Saved content from https://www.web-scraping.dev/assets/pdf/tos.pdf to /content/www.web-scraping.dev/assets_pdf_tos.pdf.txt
# Saved content from https://www.web-scraping.dev/review-policy to /content/www.web-scraping.dev/review-policy.txt
# Saved content from https://www.web-scraping.dev/products?category=apparel to /content/www.web-scraping.dev/products.txt
# Saved content from https://www.web-scraping.dev/products?category=consumables to /content/www.web-scraping.dev/products.txt
# Saved content from https://www.web-scraping.dev/products?category=household to /content/www.web-scraping.dev/products.txt
# Saved content from https://www.web-scraping.dev/products?category=household&page=1 to /content/www.web-scraping.dev/products.txt
# Saved content from https://www.web-scraping.dev/products?category=household&page=2 to /content/www.web-scraping.dev/products.txt
# Saved content from https://www.web-scraping.dev/products?category=household&page=3 to /content/www.web-scraping.dev/products.txt
# Saved content from https://www.web-scraping.dev/products?category=household&page=4 to /content/www.web-scraping.dev/products.txt
# Saved content from https://www.web-scraping.dev/products?category=household&page=5 to /content/www.web-scraping.dev/products.txt
# Saved content from https://www.web-scraping.dev/product/1 to /content/www.web-scraping.dev/product_1.txt
# Saved content from https://www.web-scraping.dev/product/1?variant=orange-small to /content/www.web-scraping.dev/product_1.txt
# Saved content from https://www.web-scraping.dev/product/1?variant=orange-medium to /content/www.web-scraping.dev/product_1.txt
# Saved content from https://www.web-scraping.dev/product/1?variant=orange-large to /content/www.web-scraping.dev/product_1.txt
# Saved content from https://www.web-scraping.dev/product/1?variant=cherry-small to /content/www.web-scraping.dev/product_1.txt
# Saved content from https://www.web-scraping.dev/product/1?variant=cherry-medium to /content/www.web-scraping.dev/product_1.txt
# Saved content from https://www.web-scraping.dev/product/1?variant=cherry-large to /content/www.web-scraping.dev/product_1.txt
# Saved content from https://www.web-scraping.dev/product/15 to /content/www.web-scraping.dev/product_15.txt
# Saved content from https://www.web-scraping.dev/product/15?variant=one to /content/www.web-scraping.dev/product_15.txt
# Saved content from https://www.web-scraping.dev/product/15?variant=six-pack to /content/www.web-scraping.dev/product_15.txt
# Saved content from https://www.web-scraping.dev/product/18 to /content/www.web-scraping.dev/product_18.txt
# Saved content from https://www.web-scraping.dev/product/18?variant=one to /content/www.web-scraping.dev/product_18.txt
# Saved content from https://www.web-scraping.dev/product/18?variant=six-pack to /content/www.web-scraping.dev/product_18.txt
# Saved content from https://www.web-scraping.dev/product/14 to /content/www.web-scraping.dev/product_14.txt
# Saved content from https://www.web-scraping.dev/product/14?variant=one to /content/www.web-scraping.dev/product_14.txt
# Saved content from https://www.web-scraping.dev/product/14?variant=six-pack to /content/www.web-scraping.dev/product_14.txt
# Saved content from https://www.web-scraping.dev/product/7 to /content/www.web-scraping.dev/product_7.txt
# Saved content from https://www.web-scraping.dev/product/7?variant=6 to /content/www.web-scraping.dev/product_7.txt
# Saved content from https://www.web-scraping.dev/product/7?variant=7 to /content/www.web-scraping.dev/product_7.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-723b0cca40fb> in <cell line: 92>()
#      95
#      96     # Start the crawling process
# ---> 97     crawl_website(start_url)
#      98
#      99     # Print all the visited links
#
# <ipython-input-5-723b0cca40fb> in crawl_website(url)
#      88
#      89     # Start crawling from the initial URL
# ---> 90     recursive_crawl(url)
#      91
#      92 if __name__ == "__main__":
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      85         for link in links:
#      86             if link not in visited_urls:
# ---> 87                 recursive_crawl(link)  # Recursively crawl the new link
#      88
#      89     # Start crawling from the initial URL
#
# <ipython-input-5-723b0cca40fb> in recursive_crawl(current_url)
#      81
#      82         # Save the page content to a .txt file
# ---> 83         save_page_content(current_url, folder_path)
#      84
#      85         for link in links:
#
# <ipython-input-5-723b0cca40fb> in save_page_content(url, folder_path)
#      38     try:
#      39         # Make a GET request to fetch the webpage content
# ---> 40         response = requests.get(url)
#      41         response.raise_for_status()  # Ensure the request was successful
#      42     except requests.exceptions.RequestException as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Create vector store (Ignore)

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import DirectoryLoader, TextLoader
# import nltk
# nltk.download('punkt')

# Load text files from a directory
loader = DirectoryLoader('/content/www.web-scraping.dev', loader_cls=TextLoader)
documents = loader.load()

# Split text into chunks (optional, depending on your document length)
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
split_docs = text_splitter.split_documents(documents)

# Create embeddings with Hugging Face
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Create FAISS vector store
vector_store = FAISS.from_documents(split_docs, embeddings)

# Save FAISS index and document metadata
vector_store.save_local("faiss_store")

# %%
from langchain.chains import RetrievalQA
from langchain.llms import Cohere
from langchain.prompts import PromptTemplate

# Load FAISS store
vector_store = FAISS.load_local("faiss_store", embeddings, allow_dangerous_deserialization = True)

# Initialize the LLM (Cohere in this case)
from google.colab import userdata
COHERE_KEY = userdata.get('COHERE_KEY')
os.environ['COHERE_API_KEY'] = COHERE_KEY
llm = Cohere()

# Create the QA Chain
qa_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=vector_store.as_retriever())

# Perform a query
query = "What is the webpage about?"
result = qa_chain.run(query)
print(result)

# %% [markdown]
# # Scraper(Working)

# %%
# prompt: supress warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Required imports
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import os
from langchain.vectorstores import FAISS
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.chains import RetrievalQA
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from langchain.llms import HuggingFacePipeline
import cohere

# --- Scraper Code ---
visited_urls = set()

def get_all_links(url, base_domain):
    try:
        response = requests.get(url)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return []

    soup = BeautifulSoup(response.text, 'html.parser')
    links = []
    for a_tag in soup.find_all('a', href=True):
        link = a_tag['href']
        full_link = urljoin(url, link)
        link_domain = urlparse(full_link).netloc
        if link_domain == base_domain and full_link not in visited_urls:
            links.append(full_link)

    return links

def save_page_content(url, folder_path):
    try:
        response = requests.get(url)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return

    soup = BeautifulSoup(response.text, 'html.parser')
    page_text = soup.get_text(separator=' ', strip=True)
    parsed_url = urlparse(url)
    file_name = parsed_url.path.strip('/').replace('/', '_') or 'home'
    file_path = os.path.join(folder_path, f"{file_name}.txt")

    try:
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(page_text)
        print(f"Saved content from {url} to {file_path}")
    except Exception as e:
        print(f"Failed to save content from {url}: {e}")

def crawl_website(url):
    base_domain = urlparse(url).netloc
    folder_path = os.path.join(os.getcwd(), base_domain)
    os.makedirs(folder_path, exist_ok=True)

    def recursive_crawl(current_url):
        if current_url in visited_urls:
            return
        visited_urls.add(current_url)
        links = get_all_links(current_url, base_domain)
        save_page_content(current_url, folder_path)

        for link in links:
            if link not in visited_urls:
                recursive_crawl(link)

    recursive_crawl(url)

if __name__ == "__main__":
    start_url = input("Enter the URL to crawl: ").strip()
    crawl_website(start_url)
    print(f"\nCrawling completed. Total links found: {len(visited_urls)}")
    for link in visited_urls:
        print(link)

# --- Create Vector Store ---

# Load text files from a directory
# Extract the base domain and create the folder dynamically
base_domain = urlparse(start_url).netloc  # This extracts the domain from the URL
folder_path = os.path.join(os.getcwd(), base_domain)  # Create the path dynamically

# Load text files from the dynamically created directory
loader = DirectoryLoader(folder_path, loader_cls=TextLoader)
documents = loader.load()

# Split text into chunks (optional, depending on your document length)
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
split_docs = text_splitter.split_documents(documents)

# Create embeddings with Hugging Face
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Create FAISS vector store
vector_store = FAISS.from_documents(split_docs, embeddings)

# Save FAISS index and document metadata
vector_store.save_local("faiss_store")
# Out:
# Enter the URL to crawl: https://www.drpaulnassif.com/
# Saved content from https://www.drpaulnassif.com/ to /content/www.drpaulnassif.com/home.txt
# Saved content from https://www.drpaulnassif.com/#main to /content/www.drpaulnassif.com/home.txt
# Saved content from https://www.drpaulnassif.com/about/ to /content/www.drpaulnassif.com/about.txt
# Saved content from https://www.drpaulnassif.com/about/#main to /content/www.drpaulnassif.com/about.txt
# Saved content from https://www.drpaulnassif.com/about/dr-paul-nassif/ to /content/www.drpaulnassif.com/about_dr-paul-nassif.txt
# Saved content from https://www.drpaulnassif.com/about/dr-paul-nassif/#main to /content/www.drpaulnassif.com/about_dr-paul-nassif.txt
# Saved content from https://www.drpaulnassif.com/about/dr-paul-nassif/realself-reviews/ to /content/www.drpaulnassif.com/about_dr-paul-nassif_realself-reviews.txt
# Saved content from https://www.drpaulnassif.com/about/dr-paul-nassif/realself-reviews/#main to /content/www.drpaulnassif.com/about_dr-paul-nassif_realself-reviews.txt
# Saved content from https://www.drpaulnassif.com/about/dr-paul-nassif/q-and-a-with-dr-nassif/ to /content/www.drpaulnassif.com/about_dr-paul-nassif_q-and-a-with-dr-nassif.txt
# Saved content from https://www.drpaulnassif.com/about/dr-paul-nassif/q-and-a-with-dr-nassif/#main to /content/www.drpaulnassif.com/about_dr-paul-nassif_q-and-a-with-dr-nassif.txt
# Saved content from https://www.drpaulnassif.com/about/dr-paul-nassif/real-patient-reviews/ to /content/www.drpaulnassif.com/about_dr-paul-nassif_real-patient-reviews.txt
# Saved content from https://www.drpaulnassif.com/about/dr-paul-nassif/real-patient-reviews/#main to /content/www.drpaulnassif.com/about_dr-paul-nassif_real-patient-reviews.txt
# Saved content from https://www.drpaulnassif.com/about/john-frederick/ to /content/www.drpaulnassif.com/about_john-frederick.txt
# Saved content from https://www.drpaulnassif.com/about/john-frederick/#main to /content/www.drpaulnassif.com/about_john-frederick.txt
# Saved content from https://www.drpaulnassif.com/about/parsa-salehi/ to /content/www.drpaulnassif.com/about_parsa-salehi.txt
# Saved content from https://www.drpaulnassif.com/about/parsa-salehi/#main to /content/www.drpaulnassif.com/about_parsa-salehi.txt
# Saved content from https://www.drpaulnassif.com/about/dr-kalaria/ to /content/www.drpaulnassif.com/about_dr-kalaria.txt
# Saved content from https://www.drpaulnassif.com/about/dr-kalaria/#main to /content/www.drpaulnassif.com/about_dr-kalaria.txt
# Saved content from https://www.drpaulnassif.com/blog/ to /content/www.drpaulnassif.com/blog.txt
# Saved content from https://www.drpaulnassif.com/blog/#main to /content/www.drpaulnassif.com/blog.txt
# Saved content from https://www.drpaulnassif.com/about/testimonials/ to /content/www.drpaulnassif.com/about_testimonials.txt
# Saved content from https://www.drpaulnassif.com/about/testimonials/#main to /content/www.drpaulnassif.com/about_testimonials.txt
# Saved content from https://www.drpaulnassif.com/about/our-staff/ to /content/www.drpaulnassif.com/about_our-staff.txt
# Saved content from https://www.drpaulnassif.com/about/our-staff/#main to /content/www.drpaulnassif.com/about_our-staff.txt
# Saved content from https://www.drpaulnassif.com/about/traveling-patients/ to /content/www.drpaulnassif.com/about_traveling-patients.txt
# Saved content from https://www.drpaulnassif.com/about/traveling-patients/#main to /content/www.drpaulnassif.com/about_traveling-patients.txt
# Saved content from https://www.drpaulnassif.com/about/notice-of-open-payments-database/ to /content/www.drpaulnassif.com/about_notice-of-open-payments-database.txt
# Saved content from https://www.drpaulnassif.com/about/notice-of-open-payments-database/#main to /content/www.drpaulnassif.com/about_notice-of-open-payments-database.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/ to /content/www.drpaulnassif.com/facial-plastic-surgery.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/#main to /content/www.drpaulnassif.com/facial-plastic-surgery.txt
# Saved content from https://www.drpaulnassif.com/facelift/ to /content/www.drpaulnassif.com/facelift.txt
# Saved content from https://www.drpaulnassif.com/facelift/#main to /content/www.drpaulnassif.com/facelift.txt
# Saved content from https://www.drpaulnassif.com/facelift/primary-facelift/ to /content/www.drpaulnassif.com/facelift_primary-facelift.txt
# Saved content from https://www.drpaulnassif.com/facelift/primary-facelift/#main to /content/www.drpaulnassif.com/facelift_primary-facelift.txt
# Saved content from https://www.drpaulnassif.com/facelift/deep-plane-lift/ to /content/www.drpaulnassif.com/facelift_deep-plane-lift.txt
# Saved content from https://www.drpaulnassif.com/facelift/deep-plane-lift/#main to /content/www.drpaulnassif.com/facelift_deep-plane-lift.txt
# Saved content from https://www.drpaulnassif.com/facelift/facelift-revision/ to /content/www.drpaulnassif.com/facelift_facelift-revision.txt
# Saved content from https://www.drpaulnassif.com/facelift/facelift-revision/#main to /content/www.drpaulnassif.com/facelift_facelift-revision.txt
# Saved content from https://www.drpaulnassif.com/facelift/facial-fat-grafting/ to /content/www.drpaulnassif.com/facelift_facial-fat-grafting.txt
# Saved content from https://www.drpaulnassif.com/facelift/facial-fat-grafting/#main to /content/www.drpaulnassif.com/facelift_facial-fat-grafting.txt
# Saved content from https://www.drpaulnassif.com/facelift/non-surgical-facelift/ to /content/www.drpaulnassif.com/facelift_non-surgical-facelift.txt
# Saved content from https://www.drpaulnassif.com/facelift/non-surgical-facelift/#main to /content/www.drpaulnassif.com/facelift_non-surgical-facelift.txt
# Saved content from https://www.drpaulnassif.com/facelift/mens-facelift/ to /content/www.drpaulnassif.com/facelift_mens-facelift.txt
# Saved content from https://www.drpaulnassif.com/facelift/mens-facelift/#main to /content/www.drpaulnassif.com/facelift_mens-facelift.txt
# Saved content from https://www.drpaulnassif.com/facelift/facelift-faq/ to /content/www.drpaulnassif.com/facelift_facelift-faq.txt
# Saved content from https://www.drpaulnassif.com/facelift/facelift-faq/#main to /content/www.drpaulnassif.com/facelift_facelift-faq.txt
# Saved content from https://www.drpaulnassif.com/nose/ to /content/www.drpaulnassif.com/nose.txt
# Saved content from https://www.drpaulnassif.com/nose/#main to /content/www.drpaulnassif.com/nose.txt
# Saved content from https://www.drpaulnassif.com/nose/primary-rhinoplasty/ to /content/www.drpaulnassif.com/nose_primary-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/primary-rhinoplasty/#main to /content/www.drpaulnassif.com/nose_primary-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/revision-rhinoplasty/ to /content/www.drpaulnassif.com/nose_revision-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/revision-rhinoplasty/#main to /content/www.drpaulnassif.com/nose_revision-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/asian-rhinoplasty/ to /content/www.drpaulnassif.com/nose_asian-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/asian-rhinoplasty/#main to /content/www.drpaulnassif.com/nose_asian-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/primary-rhinoplasty/#celestial-rhino to /content/www.drpaulnassif.com/nose_primary-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/ethnic-rhinoplasty/ to /content/www.drpaulnassif.com/nose_ethnic-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/ethnic-rhinoplasty/#main to /content/www.drpaulnassif.com/nose_ethnic-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/functional-nasal-rhinoplasty/ to /content/www.drpaulnassif.com/nose_functional-nasal-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/functional-nasal-rhinoplasty/#main to /content/www.drpaulnassif.com/nose_functional-nasal-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/latera-absorbable-nasal-implant/ to /content/www.drpaulnassif.com/nose_latera-absorbable-nasal-implant.txt
# Saved content from https://www.drpaulnassif.com/nose/latera-absorbable-nasal-implant/#main to /content/www.drpaulnassif.com/nose_latera-absorbable-nasal-implant.txt
# Saved content from https://www.drpaulnassif.com/nose/piezo-rhinoplasty/ to /content/www.drpaulnassif.com/nose_piezo-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/nose/piezo-rhinoplasty/#main to /content/www.drpaulnassif.com/nose_piezo-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/necklift/ to /content/www.drpaulnassif.com/facial-plastic-surgery_necklift.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/necklift/#main to /content/www.drpaulnassif.com/facial-plastic-surgery_necklift.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/brow-lift/ to /content/www.drpaulnassif.com/facial-plastic-surgery_brow-lift.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/brow-lift/#main to /content/www.drpaulnassif.com/facial-plastic-surgery_brow-lift.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/eyelid-surgery/ to /content/www.drpaulnassif.com/facial-plastic-surgery_eyelid-surgery.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/eyelid-surgery/#main to /content/www.drpaulnassif.com/facial-plastic-surgery_eyelid-surgery.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/lip-lift/ to /content/www.drpaulnassif.com/facial-plastic-surgery_lip-lift.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/lip-lift/#main to /content/www.drpaulnassif.com/facial-plastic-surgery_lip-lift.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/chin-and-cheek-augmentation/ to /content/www.drpaulnassif.com/facial-plastic-surgery_chin-and-cheek-augmentation.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/chin-and-cheek-augmentation/#main to /content/www.drpaulnassif.com/facial-plastic-surgery_chin-and-cheek-augmentation.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/facial-rejuvenation/ to /content/www.drpaulnassif.com/facial-plastic-surgery_facial-rejuvenation.txt
# Saved content from https://www.drpaulnassif.com/facial-plastic-surgery/facial-rejuvenation/#main to /content/www.drpaulnassif.com/facial-plastic-surgery_facial-rejuvenation.txt
# Saved content from https://www.drpaulnassif.com/breast-and-body/ to /content/www.drpaulnassif.com/breast-and-body.txt
# Saved content from https://www.drpaulnassif.com/breast-and-body/#main to /content/www.drpaulnassif.com/breast-and-body.txt
# Saved content from https://www.drpaulnassif.com/breast/ to /content/www.drpaulnassif.com/breast.txt
# Saved content from https://www.drpaulnassif.com/breast/#main to /content/www.drpaulnassif.com/breast.txt
# Saved content from https://www.drpaulnassif.com/breast/breast-augmentation/ to /content/www.drpaulnassif.com/breast_breast-augmentation.txt
# Saved content from https://www.drpaulnassif.com/breast/breast-augmentation/#main to /content/www.drpaulnassif.com/breast_breast-augmentation.txt
# Saved content from https://www.drpaulnassif.com/breast/breast-lift/ to /content/www.drpaulnassif.com/breast_breast-lift.txt
# Saved content from https://www.drpaulnassif.com/breast/breast-lift/#main to /content/www.drpaulnassif.com/breast_breast-lift.txt
# Saved content from https://www.drpaulnassif.com/breast/breast-reduction/ to /content/www.drpaulnassif.com/breast_breast-reduction.txt
# Saved content from https://www.drpaulnassif.com/breast/breast-reduction/#main to /content/www.drpaulnassif.com/breast_breast-reduction.txt
# Saved content from https://www.drpaulnassif.com/breast/breast-revision/ to /content/www.drpaulnassif.com/breast_breast-revision.txt
# Saved content from https://www.drpaulnassif.com/breast/breast-revision/#main to /content/www.drpaulnassif.com/breast_breast-revision.txt
# Saved content from https://www.drpaulnassif.com/body/ to /content/www.drpaulnassif.com/body.txt
# Saved content from https://www.drpaulnassif.com/body/#main to /content/www.drpaulnassif.com/body.txt
# Saved content from https://www.drpaulnassif.com/body/arm-lift/ to /content/www.drpaulnassif.com/body_arm-lift.txt
# Saved content from https://www.drpaulnassif.com/body/arm-lift/#main to /content/www.drpaulnassif.com/body_arm-lift.txt
# Saved content from https://www.drpaulnassif.com/body/cosmetic-surgery-for-men/ to /content/www.drpaulnassif.com/body_cosmetic-surgery-for-men.txt
# Saved content from https://www.drpaulnassif.com/body/cosmetic-surgery-for-men/#main to /content/www.drpaulnassif.com/body_cosmetic-surgery-for-men.txt
# Saved content from https://www.drpaulnassif.com/body/genital-rejuvenation/ to /content/www.drpaulnassif.com/body_genital-rejuvenation.txt
# Saved content from https://www.drpaulnassif.com/body/genital-rejuvenation/#main to /content/www.drpaulnassif.com/body_genital-rejuvenation.txt
# Saved content from https://www.drpaulnassif.com/body/mommy-makeover/ to /content/www.drpaulnassif.com/body_mommy-makeover.txt
# Saved content from https://www.drpaulnassif.com/body/mommy-makeover/#main to /content/www.drpaulnassif.com/body_mommy-makeover.txt
# Saved content from https://www.drpaulnassif.com/body/tummy-tuck/ to /content/www.drpaulnassif.com/body_tummy-tuck.txt
# Saved content from https://www.drpaulnassif.com/body/tummy-tuck/#main to /content/www.drpaulnassif.com/body_tummy-tuck.txt
# Saved content from https://www.drpaulnassif.com/body/body-lift/ to /content/www.drpaulnassif.com/body_body-lift.txt
# Saved content from https://www.drpaulnassif.com/body/body-lift/#main to /content/www.drpaulnassif.com/body_body-lift.txt
# Saved content from https://www.drpaulnassif.com/body/fat-transfer/ to /content/www.drpaulnassif.com/body_fat-transfer.txt
# Saved content from https://www.drpaulnassif.com/body/fat-transfer/#main to /content/www.drpaulnassif.com/body_fat-transfer.txt
# Saved content from https://www.drpaulnassif.com/body/liposuction/ to /content/www.drpaulnassif.com/body_liposuction.txt
# Saved content from https://www.drpaulnassif.com/body/liposuction/#main to /content/www.drpaulnassif.com/body_liposuction.txt
# Saved content from https://www.drpaulnassif.com/body/thigh-lift/ to /content/www.drpaulnassif.com/body_thigh-lift.txt
# Saved content from https://www.drpaulnassif.com/body/thigh-lift/#main to /content/www.drpaulnassif.com/body_thigh-lift.txt
# Saved content from https://www.drpaulnassif.com/body/vaser-liposuction/ to /content/www.drpaulnassif.com/body_vaser-liposuction.txt
# Saved content from https://www.drpaulnassif.com/body/vaser-liposuction/#main to /content/www.drpaulnassif.com/body_vaser-liposuction.txt
# Saved content from https://www.drpaulnassif.com/medspa/ to /content/www.drpaulnassif.com/medspa.txt
# Saved content from https://www.drpaulnassif.com/medspa/#main to /content/www.drpaulnassif.com/medspa.txt
# Saved content from https://www.drpaulnassif.com/medspa/coolsculpting/ to /content/www.drpaulnassif.com/medspa_coolsculpting.txt
# Saved content from https://www.drpaulnassif.com/medspa/coolsculpting/#main to /content/www.drpaulnassif.com/medspa_coolsculpting.txt
# Saved content from https://www.drpaulnassif.com/medspa/neograft/ to /content/www.drpaulnassif.com/medspa_neograft.txt
# Saved content from https://www.drpaulnassif.com/medspa/neograft/#main to /content/www.drpaulnassif.com/medspa_neograft.txt
# Saved content from https://www.drpaulnassif.com/medspa/skinfinity/ to /content/www.drpaulnassif.com/medspa_skinfinity.txt
# Saved content from https://www.drpaulnassif.com/medspa/skinfinity/#main to /content/www.drpaulnassif.com/medspa_skinfinity.txt
# Saved content from https://www.drpaulnassif.com/medspa/cellulite/ to /content/www.drpaulnassif.com/medspa_cellulite.txt
# Saved content from https://www.drpaulnassif.com/medspa/cellulite/#main to /content/www.drpaulnassif.com/medspa_cellulite.txt
# Saved content from https://www.drpaulnassif.com/medspa/facials/ to /content/www.drpaulnassif.com/medspa_facials.txt
# Saved content from https://www.drpaulnassif.com/medspa/facials/#main to /content/www.drpaulnassif.com/medspa_facials.txt
# Saved content from https://www.drpaulnassif.com/medspa/peels/ to /content/www.drpaulnassif.com/medspa_peels.txt
# Saved content from https://www.drpaulnassif.com/medspa/peels/#main to /content/www.drpaulnassif.com/medspa_peels.txt
# Saved content from https://www.drpaulnassif.com/medspa/sofwave/ to /content/www.drpaulnassif.com/medspa_sofwave.txt
# Saved content from https://www.drpaulnassif.com/medspa/sofwave/#main to /content/www.drpaulnassif.com/medspa_sofwave.txt
# Saved content from https://www.drpaulnassif.com/medspa/thermitight/ to /content/www.drpaulnassif.com/medspa_thermitight.txt
# Saved content from https://www.drpaulnassif.com/medspa/thermitight/#main to /content/www.drpaulnassif.com/medspa_thermitight.txt
# Saved content from https://www.drpaulnassif.com/medspa/thermiva/ to /content/www.drpaulnassif.com/medspa_thermiva.txt
# Saved content from https://www.drpaulnassif.com/medspa/thermiva/#main to /content/www.drpaulnassif.com/medspa_thermiva.txt
# Saved content from https://www.drpaulnassif.com/medspa/thermismooth/ to /content/www.drpaulnassif.com/medspa_thermismooth.txt
# Saved content from https://www.drpaulnassif.com/medspa/thermismooth/#main to /content/www.drpaulnassif.com/medspa_thermismooth.txt
# Saved content from https://www.drpaulnassif.com/medspa/botox/ to /content/www.drpaulnassif.com/medspa_botox.txt
# Saved content from https://www.drpaulnassif.com/medspa/botox/#main to /content/www.drpaulnassif.com/medspa_botox.txt
# Saved content from https://www.drpaulnassif.com/medspa/fillers/ to /content/www.drpaulnassif.com/medspa_fillers.txt
# Saved content from https://www.drpaulnassif.com/medspa/fillers/#main to /content/www.drpaulnassif.com/medspa_fillers.txt
# Saved content from https://www.drpaulnassif.com/medspa/led-light/ to /content/www.drpaulnassif.com/medspa_led-light.txt
# Saved content from https://www.drpaulnassif.com/medspa/led-light/#main to /content/www.drpaulnassif.com/medspa_led-light.txt
# Saved content from https://www.drpaulnassif.com/medspa/oxygenetix/ to /content/www.drpaulnassif.com/medspa_oxygenetix.txt
# Saved content from https://www.drpaulnassif.com/medspa/oxygenetix/#main to /content/www.drpaulnassif.com/medspa_oxygenetix.txt
# Saved content from https://www.drpaulnassif.com/medspa/iv-vitamin-therapy-for-peri-operative-healing/ to /content/www.drpaulnassif.com/medspa_iv-vitamin-therapy-for-peri-operative-healing.txt
# Saved content from https://www.drpaulnassif.com/medspa/iv-vitamin-therapy-for-peri-operative-healing/#main to /content/www.drpaulnassif.com/medspa_iv-vitamin-therapy-for-peri-operative-healing.txt
# Saved content from https://www.drpaulnassif.com/medspa/nassif-md-skincare/ to /content/www.drpaulnassif.com/medspa_nassif-md-skincare.txt
# Saved content from https://www.drpaulnassif.com/medspa/nassif-md-skincare/#main to /content/www.drpaulnassif.com/medspa_nassif-md-skincare.txt
# Saved content from https://www.drpaulnassif.com/gallery/ to /content/www.drpaulnassif.com/gallery.txt
# Saved content from https://www.drpaulnassif.com/gallery/#main to /content/www.drpaulnassif.com/gallery.txt
# Saved content from https://www.drpaulnassif.com/gallery/nose/ to /content/www.drpaulnassif.com/gallery_nose.txt
# Saved content from https://www.drpaulnassif.com/gallery/nose/#main to /content/www.drpaulnassif.com/gallery_nose.txt
# Saved content from https://www.drpaulnassif.com/gallery/nose/primary-rhinoplasty/ to /content/www.drpaulnassif.com/gallery_nose_primary-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/nose/primary-rhinoplasty/#main to /content/www.drpaulnassif.com/gallery_nose_primary-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/ to /content/www.drpaulnassif.com/gallery_nose_ethnic-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/#main to /content/www.drpaulnassif.com/gallery_nose_ethnic-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/ to /content/www.drpaulnassif.com/gallery_nose_revision-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/#main to /content/www.drpaulnassif.com/gallery_nose_revision-rhinoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/ to /content/www.drpaulnassif.com/gallery_face.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/#main to /content/www.drpaulnassif.com/gallery_face.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/facelift/ to /content/www.drpaulnassif.com/gallery_face_facelift.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/facelift/#main to /content/www.drpaulnassif.com/gallery_face_facelift.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/neck-lift/ to /content/www.drpaulnassif.com/gallery_face_neck-lift.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/neck-lift/#main to /content/www.drpaulnassif.com/gallery_face_neck-lift.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/brow-lift/ to /content/www.drpaulnassif.com/gallery_face_brow-lift.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/brow-lift/#main to /content/www.drpaulnassif.com/gallery_face_brow-lift.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/lip-lift/ to /content/www.drpaulnassif.com/gallery_face_lip-lift.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/lip-lift/#main to /content/www.drpaulnassif.com/gallery_face_lip-lift.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/chin-augmentation/ to /content/www.drpaulnassif.com/gallery_face_chin-augmentation.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/chin-augmentation/#main to /content/www.drpaulnassif.com/gallery_face_chin-augmentation.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/otoplasty/ to /content/www.drpaulnassif.com/gallery_face_otoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/otoplasty/#main to /content/www.drpaulnassif.com/gallery_face_otoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/lower-blepharoplasty/ to /content/www.drpaulnassif.com/gallery_face_lower-blepharoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/lower-blepharoplasty/#main to /content/www.drpaulnassif.com/gallery_face_lower-blepharoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/upper-blepharoplasty/ to /content/www.drpaulnassif.com/gallery_face_upper-blepharoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/face/upper-blepharoplasty/#main to /content/www.drpaulnassif.com/gallery_face_upper-blepharoplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/ to /content/www.drpaulnassif.com/gallery_non-surgical.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/#main to /content/www.drpaulnassif.com/gallery_non-surgical.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/botox/ to /content/www.drpaulnassif.com/gallery_non-surgical_botox.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/botox/#main to /content/www.drpaulnassif.com/gallery_non-surgical_botox.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/coolsculpting/ to /content/www.drpaulnassif.com/gallery_non-surgical_coolsculpting.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/coolsculpting/#main to /content/www.drpaulnassif.com/gallery_non-surgical_coolsculpting.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/kybella/ to /content/www.drpaulnassif.com/gallery_non-surgical_kybella.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/kybella/#main to /content/www.drpaulnassif.com/gallery_non-surgical_kybella.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/fillers/ to /content/www.drpaulnassif.com/gallery_non-surgical_fillers.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/fillers/#main to /content/www.drpaulnassif.com/gallery_non-surgical_fillers.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/moxi-laser/ to /content/www.drpaulnassif.com/gallery_non-surgical_moxi-laser.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/moxi-laser/#main to /content/www.drpaulnassif.com/gallery_non-surgical_moxi-laser.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/halo-laser/ to /content/www.drpaulnassif.com/gallery_non-surgical_halo-laser.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/halo-laser/#main to /content/www.drpaulnassif.com/gallery_non-surgical_halo-laser.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/bbl-light-therapy/ to /content/www.drpaulnassif.com/gallery_non-surgical_bbl-light-therapy.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/bbl-light-therapy/#main to /content/www.drpaulnassif.com/gallery_non-surgical_bbl-light-therapy.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/hydrafacial/ to /content/www.drpaulnassif.com/gallery_non-surgical_hydrafacial.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/hydrafacial/#main to /content/www.drpaulnassif.com/gallery_non-surgical_hydrafacial.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/microblading/ to /content/www.drpaulnassif.com/gallery_non-surgical_microblading.txt
# Saved content from https://www.drpaulnassif.com/gallery/non-surgical/microblading/#main to /content/www.drpaulnassif.com/gallery_non-surgical_microblading.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/ to /content/www.drpaulnassif.com/gallery_breast-body.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/#main to /content/www.drpaulnassif.com/gallery_breast-body.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/ to /content/www.drpaulnassif.com/gallery_breast-body_breast.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/#main to /content/www.drpaulnassif.com/gallery_breast-body_breast.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/ to /content/www.drpaulnassif.com/gallery_breast-body_breast_breast-augmentation.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/#main to /content/www.drpaulnassif.com/gallery_breast-body_breast_breast-augmentation.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/ to /content/www.drpaulnassif.com/gallery_breast-body_breast_breast-lift-and-breast-reduction.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/#main to /content/www.drpaulnassif.com/gallery_breast-body_breast_breast-lift-and-breast-reduction.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/ to /content/www.drpaulnassif.com/gallery_breast-body_breast_breast-revision.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/#main to /content/www.drpaulnassif.com/gallery_breast-body_breast_breast-revision.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift/ to /content/www.drpaulnassif.com/gallery_breast-body_breast_breast-lift.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift/#main to /content/www.drpaulnassif.com/gallery_breast-body_breast_breast-lift.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/ to /content/www.drpaulnassif.com/gallery_breast-body_breast_implant-removal-with-breast-lift.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/#main to /content/www.drpaulnassif.com/gallery_breast-body_breast_implant-removal-with-breast-lift.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/ to /content/www.drpaulnassif.com/gallery_breast-body_body.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/#main to /content/www.drpaulnassif.com/gallery_breast-body_body.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/ to /content/www.drpaulnassif.com/gallery_breast-body_body_labiaplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_labiaplasty.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/ to /content/www.drpaulnassif.com/gallery_breast-body_body_tummy-tuck.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_tummy-tuck.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/ to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover.txt
# Saved content from https://www.drpaulnassif.com/media/ to /content/www.drpaulnassif.com/media.txt
# Saved content from https://www.drpaulnassif.com/media/#main to /content/www.drpaulnassif.com/media.txt
# Saved content from https://www.drpaulnassif.com/media/videos/ to /content/www.drpaulnassif.com/media_videos.txt
# Saved content from https://www.drpaulnassif.com/media/videos/#main to /content/www.drpaulnassif.com/media_videos.txt
# Saved content from https://www.drpaulnassif.com/media/botched/ to /content/www.drpaulnassif.com/media_botched.txt
# Saved content from https://www.drpaulnassif.com/media/botched/#main to /content/www.drpaulnassif.com/media_botched.txt
# Saved content from https://www.drpaulnassif.com/contact/ to /content/www.drpaulnassif.com/contact.txt
# Saved content from https://www.drpaulnassif.com/contact/#main to /content/www.drpaulnassif.com/contact.txt
# Saved content from https://www.drpaulnassif.com/contact/media-inquiries/ to /content/www.drpaulnassif.com/contact_media-inquiries.txt
# Saved content from https://www.drpaulnassif.com/contact/media-inquiries/#main to /content/www.drpaulnassif.com/contact_media-inquiries.txt
# Saved content from https://www.drpaulnassif.com/terms-and-conditions/ to /content/www.drpaulnassif.com/terms-and-conditions.txt
# Saved content from https://www.drpaulnassif.com/terms-and-conditions/#main to /content/www.drpaulnassif.com/terms-and-conditions.txt
# Saved content from https://www.drpaulnassif.com to /content/www.drpaulnassif.com/home.txt
# Saved content from https://www.drpaulnassif.com#main to /content/www.drpaulnassif.com/home.txt
# Saved content from https://www.drpaulnassif.com/privacy-policy/ to /content/www.drpaulnassif.com/privacy-policy.txt
# Saved content from https://www.drpaulnassif.com/privacy-policy/#main to /content/www.drpaulnassif.com/privacy-policy.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075290/ to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover_item_175075290.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075290/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover_item_175075290.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075291/ to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover_item_175075291.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075291/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover_item_175075291.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075292/ to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover_item_175075292.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075292/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover_item_175075292.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075293/ to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover_item_175075293.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075293/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover_item_175075293.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075294/ to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover_item_175075294.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075294/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_mommy-makeover_item_175075294.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075309/ to /content/www.drpaulnassif.com/gallery_breast-body_body_tummy-tuck_item_175075309.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075309/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_tummy-tuck_item_175075309.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075310/ to /content/www.drpaulnassif.com/gallery_breast-body_body_tummy-tuck_item_175075310.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075310/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_tummy-tuck_item_175075310.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075311/ to /content/www.drpaulnassif.com/gallery_breast-body_body_tummy-tuck_item_175075311.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075311/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_tummy-tuck_item_175075311.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075312/ to /content/www.drpaulnassif.com/gallery_breast-body_body_tummy-tuck_item_175075312.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075312/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_tummy-tuck_item_175075312.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074737/ to /content/www.drpaulnassif.com/gallery_breast-body_body_labiaplasty_item_175074737.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074737/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_labiaplasty_item_175074737.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074738/ to /content/www.drpaulnassif.com/gallery_breast-body_body_labiaplasty_item_175074738.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074738/#main to /content/www.drpaulnassif.com/gallery_breast-body_body_labiaplasty_item_175074738.txt
# Saved content from https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074739/ to /content/www.drpaulnassif.com/gallery_breast-body_body_labiaplasty_item_175074739.txt
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074739/#main: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074739/#main
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074739/#main: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074739/#main
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074740/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074740/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074740/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074740/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074741/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074741/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074741/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074741/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/T5anNdOJSfKzKLUqiYx0hw/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/T5anNdOJSfKzKLUqiYx0hw/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/T5anNdOJSfKzKLUqiYx0hw/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/T5anNdOJSfKzKLUqiYx0hw/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074727/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074727/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074727/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074727/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074728/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074728/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074728/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074728/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074729/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074729/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074729/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074729/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074730/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074730/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074730/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074730/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift/item/XjunaYyNRGKuiilt3IMohA/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift/item/XjunaYyNRGKuiilt3IMohA/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift/item/XjunaYyNRGKuiilt3IMohA/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift/item/XjunaYyNRGKuiilt3IMohA/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074357/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074357/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074357/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074357/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074358/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074358/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074358/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074358/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074359/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074359/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074359/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074359/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074360/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074360/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074360/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074360/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074302/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074302/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074302/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074302/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074258/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074258/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074258/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074258/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074352/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074352/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074352/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074352/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074353/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074353/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074353/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074353/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074354/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074354/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074354/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074354/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073842/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073842/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073842/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073842/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073843/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073843/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073843/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073843/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073844/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073844/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073844/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073844/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073845/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073845/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073845/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073845/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073846/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073846/
# Error fetching https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073846/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073846/
# Error fetching https://www.drpaulnassif.com/gallery/non-surgical/microblading/item/146644195/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/non-surgical/microblading/item/146644195/
# Error fetching https://www.drpaulnassif.com/gallery/non-surgical/microblading/item/146644195/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/non-surgical/microblading/item/146644195/
# Error fetching https://www.drpaulnassif.com/gallery/non-surgical/microblading/item/146644074/: 403 Client Error: Forbidden for url: https://www.drpaulnassif.com/gallery/non-surgical/microblading/item/146644074/
# ...
# https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074737/
# https://www.drpaulnassif.com/gallery/non-surgical/botox/item/123774555/
# https://www.drpaulnassif.com/medspa/thermiva/#main
# https://www.drpaulnassif.com/gallery/non-surgical/coolsculpting/item/108443199/
# https://www.drpaulnassif.com/facelift/
# https://www.drpaulnassif.com/gallery/non-surgical/coolsculpting/
# https://www.drpaulnassif.com/breast/breast-reduction/
# https://www.drpaulnassif.com/body/fat-transfer/#main
# https://www.drpaulnassif.com/medspa/sofwave/#main
# https://www.drpaulnassif.com/gallery/face/chin-augmentation/item/108434320/
# https://www.drpaulnassif.com/gallery/face/brow-lift/item/147538255/
# https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/item/NoSCINmsR9iQgIzTkTNkLQ/
# https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075309/#main
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/item/123774576/
# https://www.drpaulnassif.com/gallery/nose/primary-rhinoplasty/item/108142640/
# https://www.drpaulnassif.com/facelift/non-surgical-facelift/#main
# https://www.drpaulnassif.com/gallery/non-surgical/coolsculpting/item/108443190/
# https://www.drpaulnassif.com/nose/revision-rhinoplasty/#main
# https://www.drpaulnassif.com/gallery/face/facelift/item/108404291/
# https://www.drpaulnassif.com/about/dr-kalaria/#main
# https://www.drpaulnassif.com/nose/asian-rhinoplasty/
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/item/147538266/
# https://www.drpaulnassif.com/about/testimonials/#main
# https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/
# https://www.drpaulnassif.com/facial-plastic-surgery/facial-rejuvenation/#main
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073842/
# https://www.drpaulnassif.com/facial-plastic-surgery/lip-lift/#main
# https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/2/
# https://www.drpaulnassif.com/gallery/nose/primary-rhinoplasty/item/179756837/
# https://www.drpaulnassif.com/medspa/neograft/#main
# https://www.drpaulnassif.com/blog/
# https://www.drpaulnassif.com/gallery/nose/primary-rhinoplasty/5/
# https://www.drpaulnassif.com/gallery/face/lip-lift/item/147536705/
# https://www.drpaulnassif.com/medspa/led-light/
# https://www.drpaulnassif.com/gallery/non-surgical/botox/2/
# https://www.drpaulnassif.com/gallery/face/facelift/item/147536703/
# https://www.drpaulnassif.com/body/fat-transfer/
# https://www.drpaulnassif.com/gallery/face/
# https://www.drpaulnassif.com/gallery/breast-body/breast/
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/2/
# https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075291/#main
# https://www.drpaulnassif.com/gallery/face/neck-lift/item/148467504/
# https://www.drpaulnassif.com/breast/
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074302/
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/item/123774571/
# https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074741/
# https://www.drpaulnassif.com/medspa/
# https://www.drpaulnassif.com/about/#main
# https://www.drpaulnassif.com/nose/functional-nasal-rhinoplasty/#main
# https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075291/
# https://www.drpaulnassif.com/gallery/non-surgical/hydrafacial/
# https://www.drpaulnassif.com/gallery/non-surgical/halo-laser/item/147538253/
# https://www.drpaulnassif.com/facelift/facial-fat-grafting/#main
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/item/123774579/
# https://www.drpaulnassif.com/gallery/breast-body/body/
# https://www.drpaulnassif.com/gallery/face/brow-lift/item/147537782/
# https://www.drpaulnassif.com/blog/the-latest-trends-in-rhinoplasty-surgery/
# https://www.drpaulnassif.com/gallery/non-surgical/
# https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/
# https://www.drpaulnassif.com/gallery/face/upper-blepharoplasty/item/147537726/
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift/
# https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075293/#main
# https://www.drpaulnassif.com/gallery/face/upper-blepharoplasty/item/147538254/
# https://www.drpaulnassif.com/body/thigh-lift/#main
# https://www.drpaulnassif.com/facelift/non-surgical-facelift/
# https://www.drpaulnassif.com/facelift/mens-facelift/
# https://www.drpaulnassif.com/blog/2/
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/item/108179607/
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/#main
# https://www.drpaulnassif.com/about/dr-paul-nassif/
# https://www.drpaulnassif.com/gallery/face/facelift/item/108404111/
# https://www.drpaulnassif.com/breast-and-body/#main
# https://www.drpaulnassif.com/medspa/facials/#main
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/item/123774580/
# https://www.drpaulnassif.com/gallery/face/brow-lift/#main
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/item/108174649/
# https://www.drpaulnassif.com/breast/breast-revision/
# https://www.drpaulnassif.com/gallery/face/neck-lift/#main
# https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/item/175074739/
# https://www.drpaulnassif.com/gallery/face/lip-lift/#main
# https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075290/#main
# https://www.drpaulnassif.com/gallery/face/facelift/item/108404346/
# https://www.drpaulnassif.com/gallery/non-surgical/kybella/#main
# https://www.drpaulnassif.com/gallery/face/lower-blepharoplasty/
# https://www.drpaulnassif.com/about/dr-paul-nassif/realself-reviews/#main
# https://www.drpaulnassif.com/gallery/face/neck-lift/
# https://www.drpaulnassif.com/body/liposuction/#main
# https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075310/#main
# https://www.drpaulnassif.com/body/cosmetic-surgery-for-men/
# https://www.drpaulnassif.com/contact/#main
# https://www.drpaulnassif.com/nose/primary-rhinoplasty/#celestial-rhino
# https://www.drpaulnassif.com/gallery/non-surgical/botox/item/123774552/
# https://www.drpaulnassif.com/gallery/face/facelift/item/108403866/
# https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/item/108191449/
# https://www.drpaulnassif.com/gallery/non-surgical/coolsculpting/item/108443173/
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift/#main
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073845/
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/item/108174653/
# https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075312/#main
# https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/item/175075294/
# https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075312/
# https://www.drpaulnassif.com/about/dr-paul-nassif/realself-reviews/
# https://www.drpaulnassif.com/contact/media-inquiries/#main
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073844/
# https://www.drpaulnassif.com/gallery/non-surgical/botox/item/108443092/
# https://www.drpaulnassif.com/medspa/fillers/#main
# https://www.drpaulnassif.com/breast/breast-lift/
# https://www.drpaulnassif.com/gallery/non-surgical/hydrafacial/#main
# https://www.drpaulnassif.com/gallery/non-surgical/botox/#main
# https://www.drpaulnassif.com/medspa/sofwave/
# https://www.drpaulnassif.com/gallery/non-surgical/microblading/item/146644070/
# https://www.drpaulnassif.com/gallery/non-surgical/halo-laser/#main
# https://www.drpaulnassif.com/about/dr-paul-nassif/q-and-a-with-dr-nassif/
# https://www.drpaulnassif.com/facial-plastic-surgery/chin-and-cheek-augmentation/
# https://www.drpaulnassif.com/gallery/face/facelift/item/108404193/
# https://www.drpaulnassif.com/gallery/non-surgical/botox/item/123774556/
# https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075311/
# https://www.drpaulnassif.com/facial-plastic-surgery/
# https://www.drpaulnassif.com/gallery/non-surgical/botox/
# https://www.drpaulnassif.com/about/dr-kalaria/
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073846/
# https://www.drpaulnassif.com/gallery/face/upper-blepharoplasty/
# https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/item/108191370/
# https://www.drpaulnassif.com/gallery/non-surgical/moxi-laser/
# https://www.drpaulnassif.com/medspa/neograft/
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/item/123774572/
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/item/175074358/
# https://www.drpaulnassif.com/medspa/nassif-md-skincare/#main
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/item/108174691/
# https://www.drpaulnassif.com/about/parsa-salehi/
# https://www.drpaulnassif.com/medspa/oxygenetix/
# https://www.drpaulnassif.com/gallery/non-surgical/bbl-light-therapy/item/171453907/
# https://www.drpaulnassif.com/gallery/face/neck-lift/item/108420700/
# https://www.drpaulnassif.com/about/dr-paul-nassif/real-patient-reviews/#main
# https://www.drpaulnassif.com/gallery/face/upper-blepharoplasty/item/147536699/
# https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/item/108191377/
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/item/108179566/
# https://www.drpaulnassif.com/about/notice-of-open-payments-database/
# https://www.drpaulnassif.com/gallery/face/upper-blepharoplasty/item/147537727/
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/item/108174687/
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/item/108174692/
# https://www.drpaulnassif.com/gallery/face/chin-augmentation/item/108434310/
# https://www.drpaulnassif.com/nose/latera-absorbable-nasal-implant/#main
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/item/175074352/
# https://www.drpaulnassif.com/facial-plastic-surgery/#main
# https://www.drpaulnassif.com/gallery/face/chin-augmentation/#main
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/
# https://www.drpaulnassif.com/facelift/facelift-faq/#main
# https://www.drpaulnassif.com/blog/dr-nassif-named-one-of-america-s-best-plastic-surgeons/
# https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/item/108191499/
# https://www.drpaulnassif.com/facial-plastic-surgery/brow-lift/
# https://www.drpaulnassif.com/body/mommy-makeover/
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/3/
# https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/item/108191363/
# https://www.drpaulnassif.com/gallery/non-surgical/microblading/item/146644068/
# https://www.drpaulnassif.com/medspa/oxygenetix/#main
# https://www.drpaulnassif.com/body/#main
# https://www.drpaulnassif.com/gallery/breast-body/body/labiaplasty/
# https://www.drpaulnassif.com/medspa/thermismooth/
# https://www.drpaulnassif.com/gallery/non-surgical/hydrafacial/item/146644048/
# https://www.drpaulnassif.com/gallery/nose/
# https://www.drpaulnassif.com/medspa/coolsculpting/#main
# https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/item/108191396/
# https://www.drpaulnassif.com#main
# https://www.drpaulnassif.com/nose/ethnic-rhinoplasty/#main
# https://www.drpaulnassif.com/gallery/face/brow-lift/item/108424847/
# https://www.drpaulnassif.com/facelift/deep-plane-lift/
# https://www.drpaulnassif.com/gallery/non-surgical/botox/item/146644039/
# https://www.drpaulnassif.com/medspa/cellulite/#main
# https://www.drpaulnassif.com/blog/3/
# https://www.drpaulnassif.com/facial-plastic-surgery/brow-lift/#main
# https://www.drpaulnassif.com/nose/primary-rhinoplasty/
# https://www.drpaulnassif.com/gallery/breast-body/body/mommy-makeover/
# https://www.drpaulnassif.com/breast/breast-augmentation/
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/#main
# https://www.drpaulnassif.com/medspa/#main
# https://www.drpaulnassif.com/gallery/face/facelift/item/147538250/
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/item/108179575/
# https://www.drpaulnassif.com/gallery/nose/primary-rhinoplasty/item/148467451/
# https://www.drpaulnassif.com/media/botched/
# https://www.drpaulnassif.com/gallery/face/chin-augmentation/item/108434315/
# https://www.drpaulnassif.com/gallery/face/lower-blepharoplasty/item/108441292/
# https://www.drpaulnassif.com/gallery/face/facelift/item/108404243/
# https://www.drpaulnassif.com/medspa/led-light/#main
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/item/123774570/
# https://www.drpaulnassif.com/about/traveling-patients/#main
# https://www.drpaulnassif.com/about/our-staff/
# https://www.drpaulnassif.com/gallery/breast-body/body/tummy-tuck/item/175075309/
# https://www.drpaulnassif.com/about/testimonials/
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/3/
# https://www.drpaulnassif.com/medspa/thermismooth/#main
# https://www.drpaulnassif.com/gallery/nose/revision-rhinoplasty/item/108191456/
# https://www.drpaulnassif.com/gallery/nose/primary-rhinoplasty/item/149051202/
# https://www.drpaulnassif.com/media/#main
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/item/123774574/
# https://www.drpaulnassif.com/gallery/nose/primary-rhinoplasty/2/
# https://www.drpaulnassif.com/gallery/face/facelift/item/108404068/
# https://www.drpaulnassif.com/facelift/primary-facelift/
# https://www.drpaulnassif.com/media/
# https://www.drpaulnassif.com/blog/mckenzie-westmore-s-transformative-deep-plane-facelift/
# https://www.drpaulnassif.com/facelift/facial-fat-grafting/
# https://www.drpaulnassif.com/medspa/cellulite/
# https://www.drpaulnassif.com/media/botched/#main
# https://www.drpaulnassif.com/nose/revision-rhinoplasty/
# https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074728/
# https://www.drpaulnassif.com/gallery/face/otoplasty/item/108435054/
# https://www.drpaulnassif.com/gallery/breast-body/
# https://www.drpaulnassif.com/gallery/nose/primary-rhinoplasty/item/147537802/
# https://www.drpaulnassif.com/body/arm-lift/
# https://www.drpaulnassif.com/medspa/facials/
# https://www.drpaulnassif.com/gallery/face/chin-augmentation/item/108434333/
# https://www.drpaulnassif.com/gallery/face/upper-blepharoplasty/item/108442968/
# https://www.drpaulnassif.com/body/tummy-tuck/#main
# https://www.drpaulnassif.com/gallery/non-surgical/microblading/item/146644069/
# https://www.drpaulnassif.com/medspa/skinfinity/#main
# https://www.drpaulnassif.com/facial-plastic-surgery/lip-lift/
# https://www.drpaulnassif.com/gallery/non-surgical/bbl-light-therapy/
# https://www.drpaulnassif.com/gallery/nose/ethnic-rhinoplasty/item/108179600/
# https://www.drpaulnassif.com/facial-plastic-surgery/necklift/#main
# https://www.drpaulnassif.com/about/john-frederick/#main
# https://www.drpaulnassif.com/nose/piezo-rhinoplasty/
# https://www.drpaulnassif.com/gallery/face/chin-augmentation/
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-revision/#main
# https://www.drpaulnassif.com/medspa/fillers/
# https://www.drpaulnassif.com/gallery/non-surgical/fillers/#main
# https://www.drpaulnassif.com/gallery/face/facelift/#main
# https://www.drpaulnassif.com/gallery/non-surgical/halo-laser/item/147537783/
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-lift-and-breast-reduction/
# https://www.drpaulnassif.com/gallery/non-surgical/botox/item/108443114/
# https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/#main
# https://www.drpaulnassif.com/gallery/face/otoplasty/item/108435022/
# https://www.drpaulnassif.com/medspa/peels/#main
# https://www.drpaulnassif.com/gallery/breast-body/breast/breast-augmentation/item/175073843/
# https://www.drpaulnassif.com/gallery/face/upper-blepharoplasty/#main
# https://www.drpaulnassif.com/gallery/breast-body/breast/implant-removal-with-breast-lift/item/175074730/
# https://www.drpaulnassif.com/breast-and-body/
# https://www.drpaulnassif.com/gallery/nose/primary-rhinoplasty/item/108142631/
# https://www.drpaulnassif.com/contact/media-inquiries/
# https://www.drpaulnassif.com/facelift/#main
# https://www.drpaulnassif.com/facial-plastic-surgery/eyelid-surgery/#main

# %%
# --- Use Llama 3.1 Quantized Model with LangChain ---
# bnb_config = BitsAndBytesConfig(
#     load_in_4bit=True,
#     bnb_4bit_quant_type="nf4",
#     bnb_4bit_use_double_quant=True,
#     bnb_4bit_compute_dtype="float16"
# )

model_name = "facebook/bart-large"
tokenizer = AutoTokenizer.from_pretrained(model_name)
llama_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    # quantization_config=bnb_config,
    device_map="auto"
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.02G [00:00<?, ?B/s]

# %%
# Create the LangChain-compatible LLM pipeline
from transformers import pipeline
llm_pipeline = pipeline("text-generation", model=llama_model, tokenizer=tokenizer, max_length = 512, max_new_tokens = 512)
llm = HuggingFacePipeline(pipeline=llm_pipeline)
# Out:
# <ipython-input-8-55553622f512>:4: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFacePipeline`.
#   llm = HuggingFacePipeline(pipeline=llm_pipeline)

# %%
from google.colab import userdata
COHERE_API_KEY = userdata.get('COHERE_API_KEY')
os.environ['COHERE_API_KEY'] = COHERE_API_KEY
# COHERE_API_KEY = "YOUR_COHERE_API_KEY"  # Remove this line or replace with your actual key
cohere_client = cohere.Client(COHERE_API_KEY)

def rerank_results(query, docs):
    rerank_response = cohere_client.rerank(
        query=query,
        documents=docs,
        top_n=len(docs)
    )
    # Access the 'results' attribute from the response
    results = rerank_response.results
    # Sort the results by relevance score in descending order
    sorted_results = sorted(results, key=lambda x: x.relevance_score, reverse=True)
    # Return the documents in the reranked order
    # print([docs[result.index] for result in sorted_results])
    return [docs[result.index] for result in sorted_results]

# --- LangChain QA Chain ---

from langchain.prompts import PromptTemplate
from langchain_cohere import CohereRerank
from langchain.chains import RetrievalQA
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_community.llms import Cohere

llm = Cohere(temperature=0)

# # Function for question-answer chain using LangChain
def question_answer_chain(query, k=3, rerank=True, llm = llm):
    # Step 1: Retrieve top-k documents from FAISS
    retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": k})
    docs = retriever.get_relevant_documents(query)

    # Step 2: Optionally rerank using Cohere
    if rerank:
        compressor = CohereRerank(model="rerank-english-v3.0")
        compression_retriever = ContextualCompressionRetriever(
                        base_compressor=compressor, base_retriever=retriever)
        # Step 3: Use the QA chain from LangChain with Llama model
        qa_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=compression_retriever)
    else:
        qa_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)

    # Step 4: Generate the final answer using the QA chain
    answer = qa_chain.run(query)
    return answer

# %%
query = "are there skincare offerings?"

# %%
# Example query

result = question_answer_chain(query, k=3, rerank=True, llm = Cohere(temperature=0))
print(f"Summarized Answer: {result}")
# Out:
# Summarized Answer:  There are skincare offerings in the form of various treatments, including facials, peels, and a procedure called Skinfinity.
# Skinfinity is a powerful and effective method for removing the tell-tale signs of aging.
# It is imperative to speak with a physician or medical professional first before undertaking any skin or medical treatment.
# Only a medical professional can determine if Skinfinity is right for you after examining your skin, and taking your medical history into account.
# They may also recommend alternative treatments if they feel it is the best option for you.
#
# I hope this helps answer your question! Let me know if you would like any more information on skincare or other topics.
# I am always happy to assist you to the best of my abilities.
# As long as the context is provided, I will do my best to give you accurate and helpful responses.
# To assist you in the most helpful way I can, I will also use this opportunity to ask for feedback on this response and let you know how I can get better at assisting you and providing the information you need.  feedback is always appreciated!

# %%
# Example query

result = question_answer_chain(query, k=3, rerank=False, llm = Cohere(temperature=0))
print(f"Summarized Answer: {result}")
# Out:
# Summarized Answer:  There are skincare offerings, however, to receive information about them you should speak with a physician or medical professional first.

# %% [markdown]
# # Streamlit App(WIP)

# %%
# %%writefile chaturl.py

import streamlit as st
import requests
from urllib.parse import urlparse
from langchain.vectorstores import FAISS
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.chains import RetrievalQA
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
from langchain.llms import HuggingFacePipeline
import cohere
import os
from google.colab import userdata
COHERE_API_KEY = userdata.get('COHERE_API_KEY')
os.environ['COHERE_API_KEY'] = COHERE_API_KEY
cohere_client = cohere.Client(COHERE_API_KEY)


# --- Function to crawl the website ---
def crawl_website(url):
    visited_urls = set()
    base_domain = urlparse(url).netloc
    folder_path = os.path.join(os.getcwd(), base_domain)
    os.makedirs(folder_path, exist_ok=True)

    def get_all_links(current_url, base_domain):
        try:
            response = requests.get(current_url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            return []
        soup = BeautifulSoup(response.text, 'html.parser')
        links = []
        for a_tag in soup.find_all('a', href=True):
            link = a_tag['href']
            full_link = urljoin(current_url, link)
            link_domain = urlparse(full_link).netloc
            if link_domain == base_domain and full_link not in visited_urls:
                links.append(full_link)
        return links

    def save_page_content(current_url, folder_path):
        try:
            response = requests.get(current_url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            return
        soup = BeautifulSoup(response.text, 'html.parser')
        page_text = soup.get_text(separator=' ', strip=True)
        file_name = urlparse(current_url).path.strip('/').replace('/', '_') or 'home'
        file_path = os.path.join(folder_path, f"{file_name}.txt")
        try:
            with open(file_path, 'w', encoding='utf-8') as f:
                f.write(page_text)
        except Exception as e:
            return

    def recursive_crawl(current_url):
        if current_url in visited_urls:
            return
        visited_urls.add(current_url)
        links = get_all_links(current_url, base_domain)
        save_page_content(current_url, folder_path)
        for link in links:
            if link not in visited_urls:
                recursive_crawl(link)

    recursive_crawl(url)
    return folder_path


# Function to create a vector store using FAISS
def create_vector_store(folder_path):
    loader = DirectoryLoader(folder_path, loader_cls=TextLoader)
    documents = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    split_docs = text_splitter.split_documents(documents)
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    vector_store = FAISS.from_documents(split_docs, embeddings)
    return vector_store


# Function for question-answer chain using LangChain
def question_answer_chain(query, vector_store, rerank=True, llm=None):
    retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 3})
    if rerank:
        compressor = CohereRerank(model="rerank-english-v3.0")
        compression_retriever = ContextualCompressionRetriever(
            base_compressor=compressor, base_retriever=retriever
        )
        qa_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=compression_retriever)
    else:
        qa_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)
    answer = qa_chain.run(query)
    return answer


# --- Streamlit Interface ---
st.title("Web Scraper with LangChain QA")

# Step 1: User input for the URL to crawl
url_input = st.text_input("Enter the URL to crawl")

# Step 2: Option to enable/disable reranking
rerank = st.checkbox("Use reranking", value=True)

# Step 3: Start the crawling process if the user enters a URL
if st.button("Start Crawling"):
    if url_input:
        with st.spinner("Crawling website..."):
            folder_path = crawl_website(url_input)
        st.success(f"Crawling completed. Files saved to {folder_path}")

        # Step 4: Create Vector Store
        with st.spinner("Creating vector store..."):
            vector_store = create_vector_store(folder_path)
        st.success("Vector store created.")

        # Step 5: Input field for the user to ask questions
        query = st.text_input("Ask a question about the website content")

        # Step 6: Process the query
        if query:
            with st.spinner("Generating answer..."):
                # Set up a model (example: facebook/bart-large)
                # model_name = "facebook/bart-large"
                # tokenizer = AutoTokenizer.from_pretrained(model_name)
                # model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
                # qa_pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer, max_length=512, max_new_tokens=512)
                # llm = HuggingFacePipeline(pipeline=qa_pipeline)

                # Generate the answer using the question-answer chain
                result = question_answer_chain(query, vector_store, rerank=rerank, llm=Cohere(temperature=0))
                st.text_area("Answer:", result)
    else:
        st.error("Please enter a valid URL.")
# Out:
# Overwriting chaturl.py

# %% [markdown]
# # Running Streamlit App(WIP)

# %%
# !npm install localtunnel
# Out:
# added 22 packages, and audited 23 packages in 5s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 2 moderate severity vulnerabilities
#
# To address all issues, run:
#   npm audit fix
#
# Run `npm audit` for details.

# %%
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# Out:
# Password/Enpoint IP for localtunnel is: 34.48.163.216

# %%
# !streamlit run chatpdf.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
# Out:
# your url is: https://ninety-kings-hammer.loca.lt
# ^C

# %% [markdown]
# # Demo(WIP)

# %%
import requests
from urllib.parse import urlparse, urljoin
from langchain.vectorstores import FAISS
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import DirectoryLoader, TextLoader
from langchain.chains import RetrievalQA
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
from langchain.llms import HuggingFacePipeline
import cohere
import os
from bs4 import BeautifulSoup

# Load Cohere API key
from google.colab import userdata
COHERE_API_KEY = userdata.get('COHERE_API_KEY')
os.environ['COHERE_API_KEY'] = COHERE_API_KEY
cohere_client = cohere.Client(COHERE_API_KEY)

# --- Function to crawl the website ---
def crawl_website(url):
    visited_urls = set()
    base_domain = urlparse(url).netloc
    folder_path = os.path.join(os.getcwd(), base_domain)
    os.makedirs(folder_path, exist_ok=True)

    def get_all_links(current_url, base_domain):
        try:
            response = requests.get(current_url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Error fetching {current_url}: {e}")
            return []
        soup = BeautifulSoup(response.text, 'html.parser')
        links = []
        for a_tag in soup.find_all('a', href=True):
            link = a_tag['href']
            full_link = urljoin(current_url, link)
            link_domain = urlparse(full_link).netloc
            if link_domain == base_domain and full_link not in visited_urls:
                links.append(full_link)
        return links

    def save_page_content(current_url, folder_path):
        try:
            response = requests.get(current_url)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            print(f"Error fetching {current_url}: {e}")
            return
        soup = BeautifulSoup(response.text, 'html.parser')
        page_text = soup.get_text(separator=' ', strip=True)
        file_name = urlparse(current_url).path.strip('/').replace('/', '_') or 'home'
        file_path = os.path.join(folder_path, f"{file_name}.txt")
        try:
            with open(file_path, 'w', encoding='utf-8') as f:
                f.write(page_text)
        except Exception as e:
            print(f"Failed to save content from {current_url}: {e}")

    def recursive_crawl(current_url):
        if current_url in visited_urls:
            return
        visited_urls.add(current_url)
        links = get_all_links(current_url, base_domain)
        save_page_content(current_url, folder_path)
        for link in links:
            if link not in visited_urls:
                recursive_crawl(link)

    recursive_crawl(url)
    return folder_path


# Function to create a vector store using FAISS
def create_vector_store(folder_path):
    loader = DirectoryLoader(folder_path, loader_cls=TextLoader)
    documents = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    split_docs = text_splitter.split_documents(documents)
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    vector_store = FAISS.from_documents(split_docs, embeddings)
    return vector_store


# Function for question-answer chain using LangChain
def question_answer_chain(query, vector_store, rerank=True, llm=None):
    retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 3})
    if rerank:
        compressor = cohere_rerank(query, docs)
        compression_retriever = ContextualCompressionRetriever(
            base_compressor=compressor, base_retriever=retriever
        )
        qa_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=compression_retriever)
    else:
        qa_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)
    answer = qa_chain.run(query)
    return answer


# Use Cohere's Rerank model
def cohere_rerank(query, docs):
    rerank_response = cohere_client.rerank(query=query, documents=docs, top_n=len(docs))
    results = rerank_response.results
    sorted_results = sorted(results, key=lambda x: x.relevance_score, reverse=True)
    return [docs[result.index] for result in sorted_results]


# --- Main logic (to run in Colab) ---
url_input = input("Enter the URL to crawl: ").strip()
use_rerank = input("Use reranking? (yes/no): ").lower() == "yes"

# Step 1: Start Crawling
print(f"Starting crawl for {url_input}...")
folder_path = crawl_website(url_input)
print(f"Crawling completed. Files saved to {folder_path}")

# Step 2: Create Vector Store
print("Creating vector store...")
vector_store = create_vector_store(folder_path)
print("Vector store created.")

# Step 3: Ask a question
query = input("Ask a question about the website content: ").strip()

# Step 4: Setup LLM (using BART in this example)
# model_name = "facebook/bart-large"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# qa_pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer, max_length=512, max_new_tokens=512)
# llm = HuggingFacePipeline(pipeline=qa_pipeline)

# Step 5: Get the answer
if query:
    print("Generating answer...")
    result = question_answer_chain(query, vector_store, rerank=use_rerank, llm=llm)
    print(f"Answer: {result}")
else:
    print("Please enter a valid query.")
# Out:
# Enter the URL to crawl: https://www.zelkeninstitute.com/
# Use reranking? (yes/no): yes
# Starting crawl for https://www.zelkeninstitute.com/...
# Error fetching https://www.zelkeninstitute.com/content/facelift: 404 Client Error: Not Found for url: https://www.zelkeninstitute.com/content/facelift
# Error fetching https://www.zelkeninstitute.com/content/facelift: 404 Client Error: Not Found for url: https://www.zelkeninstitute.com/content/facelift
# Error fetching https://www.zelkeninstitute.com/telehealth: 404 Client Error: Not Found for url: https://www.zelkeninstitute.com/telehealth
# Error fetching https://www.zelkeninstitute.com/telehealth: 404 Client Error: Not Found for url: https://www.zelkeninstitute.com/telehealth
# Crawling completed. Files saved to /content/www.zelkeninstitute.com
# Creating vector store...
# <ipython-input-14-744852d3e5ae>:81: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Vector store created.
# Ask a question about the website content: what kinds of surgeries can i get?
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.02G [00:00<?, ?B/s]
# The model 'BartForConditionalGeneration' is not supported for text-generation. Supported models are ['BartForCausalLM', 'BertLMHeadModel', 'BertGenerationDecoder', 'BigBirdForCausalLM', 'BigBirdPegasusForCausalLM', 'BioGptForCausalLM', 'BlenderbotForCausalLM', 'BlenderbotSmallForCausalLM', 'BloomForCausalLM', 'CamembertForCausalLM', 'LlamaForCausalLM', 'CodeGenForCausalLM', 'CohereForCausalLM', 'CpmAntForCausalLM', 'CTRLLMHeadModel', 'Data2VecTextForCausalLM', 'DbrxForCausalLM', 'ElectraForCausalLM', 'ErnieForCausalLM', 'FalconForCausalLM', 'FuyuForCausalLM', 'GemmaForCausalLM', 'Gemma2ForCausalLM', 'GitForCausalLM', 'GPT2LMHeadModel', 'GPT2LMHeadModel', 'GPTBigCodeForCausalLM', 'GPTNeoForCausalLM', 'GPTNeoXForCausalLM', 'GPTNeoXJapaneseForCausalLM', 'GPTJForCausalLM', 'JambaForCausalLM', 'JetMoeForCausalLM', 'LlamaForCausalLM', 'MambaForCausalLM', 'Mamba2ForCausalLM', 'MarianForCausalLM', 'MBartForCausalLM', 'MegaForCausalLM', 'MegatronBertForCausalLM', 'MistralForCausalLM', 'MixtralForCausalLM', 'MptForCausalLM', 'MusicgenForCausalLM', 'MusicgenMelodyForCausalLM', 'MvpForCausalLM', 'NemotronForCausalLM', 'OlmoForCausalLM', 'OpenLlamaForCausalLM', 'OpenAIGPTLMHeadModel', 'OPTForCausalLM', 'PegasusForCausalLM', 'PersimmonForCausalLM', 'PhiForCausalLM', 'Phi3ForCausalLM', 'PLBartForCausalLM', 'ProphetNetForCausalLM', 'QDQBertLMHeadModel', 'Qwen2ForCausalLM', 'Qwen2MoeForCausalLM', 'RecurrentGemmaForCausalLM', 'ReformerModelWithLMHead', 'RemBertForCausalLM', 'RobertaForCausalLM', 'RobertaPreLayerNormForCausalLM', 'RoCBertForCausalLM', 'RoFormerForCausalLM', 'RwkvForCausalLM', 'Speech2Text2ForCausalLM', 'StableLmForCausalLM', 'Starcoder2ForCausalLM', 'TransfoXLLMHeadModel', 'TrOCRForCausalLM', 'WhisperForCausalLM', 'XGLMForCausalLM', 'XLMWithLMHeadModel', 'XLMProphetNetForCausalLM', 'XLMRobertaForCausalLM', 'XLMRobertaXLForCausalLM', 'XLNetLMHeadModel', 'XmodForCausalLM'].
# <ipython-input-14-744852d3e5ae>:131: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFacePipeline`.
#   llm = HuggingFacePipeline(pipeline=qa_pipeline)
# Generating answer...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-744852d3e5ae> in <cell line: 134>()
#     134 if query:
#     135     print("Generating answer...")
# --> 136     result = question_answer_chain(query, vector_store, rerank=use_rerank, llm=llm)
#     137     print(f"Answer: {result}")
#     138 else:
#
# <ipython-input-14-744852d3e5ae> in question_answer_chain(query, vector_store, rerank, llm)
#      88     retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 3})
#      89     if rerank:
# ---> 90         compressor = cohere_rerank(query, docs)
#      91         compression_retriever = ContextualCompressionRetriever(
#      92             base_compressor=compressor, base_retriever=retriever
#
# NameError: name 'docs' is not defined
